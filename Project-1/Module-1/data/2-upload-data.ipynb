# %%
import pandas as pd

# %%
df = pd.read_csv('nyt.csv', nrows=100)
df.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# 5         1  2024-01-01 00:54:08   2024-01-01 01:26:31              1.0
# 6         2  2024-01-01 00:49:44   2024-01-01 01:15:47              2.0
# 7         1  2024-01-01 00:30:40   2024-01-01 00:58:40              0.0
# 8         2  2024-01-01 00:26:01   2024-01-01 00:54:12              1.0
# 9         2  2024-01-01 00:28:08   2024-01-01 00:29:16              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
# 5           4.70         1.0                  N           148           141
# 6          10.82         1.0                  N           138           181
# 7           3.00         1.0                  N           246           231
# 8           5.44         1.0                  N           161           261
# 9           0.04         1.0                  N           113           113
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2         17.7    1.0      0.5        0.00           0.0
# 1             1         10.0    3.5      0.5        3.75           0.0
# 2             1         23.3    3.5      0.5        3.00           0.0
# 3             1         10.0    3.5      0.5        2.00           0.0
# 4             1          7.9    3.5      0.5        3.20           0.0
# 5             1         29.6    3.5      0.5        6.90           0.0
# 6             1         45.7    6.0      0.5       10.00           0.0
# 7             2         25.4    3.5      0.5        0.00           0.0
# 8             2         31.0    1.0      0.5        0.00           0.0
# 9             2          3.0    1.0      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         22.70                   2.5         0.00
# 1                    1.0         18.75                   2.5         0.00
# 2                    1.0         31.30                   2.5         0.00
# 3                    1.0         17.00                   2.5         0.00
# 4                    1.0         16.10                   2.5         0.00
# 5                    1.0         41.50                   2.5         0.00
# 6                    1.0         64.95                   0.0         1.75
# 7                    1.0         30.40                   2.5         0.00
# 8                    1.0         36.00                   2.5         0.00
# 9                    1.0          8.00                   2.5         0.00

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "Airport_fee" REAL
# )

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine as CE

# %%
engine = CE('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data',con = engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	"Airport_fee" FLOAT(53)
# )

# %%
df_full = pd.read_csv('nyt.csv')
# Out:
# /tmp/ipykernel_23210/41505097.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_full = pd.read_csv('nyt.csv')

# %%
num_filas, num_columnas = df_full.shape
print(f'El archivo CSV tiene {num_filas} filas y {num_columnas} columnas.')
# Out:
# El archivo CSV tiene 2964624 filas y 19 columnas.

# %%
df_full.describe().round(2)
# Out:
#          VendorID  passenger_count  trip_distance  RatecodeID  PULocationID  \
# count  2964624.00       2824462.00     2964624.00  2824462.00    2964624.00
# mean         1.75             1.34           3.65        2.07        166.02
# std          0.43             0.85         225.46        9.82         63.62
# min          1.00             0.00           0.00        1.00          1.00
# 25%          2.00             1.00           1.00        1.00        132.00
# 50%          2.00             1.00           1.68        1.00        162.00
# 75%          2.00             1.00           3.11        1.00        234.00
# max          6.00             9.00      312722.30       99.00        265.00
#
#        DOLocationID  payment_type  fare_amount       extra     mta_tax  \
# count    2964624.00    2964624.00   2964624.00  2964624.00  2964624.00
# mean         165.12          1.16        18.18        1.45        0.48
# std           69.32          0.58        18.95        1.80        0.12
# min            1.00          0.00      -899.00       -7.50       -0.50
# 25%          114.00          1.00         8.60        0.00        0.50
# 50%          162.00          1.00        12.80        1.00        0.50
# 75%          234.00          1.00        20.50        2.50        0.50
# max          265.00          4.00      5000.00       14.25        4.00
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# count  2964624.00    2964624.00             2964624.00    2964624.00
# mean         3.34          0.53                   0.98         26.80
# std          3.90          2.13                   0.22         23.39
# min        -80.00        -80.00                  -1.00       -900.00
# 25%          1.00          0.00                   1.00         15.38
# 50%          2.70          0.00                   1.00         20.10
# 75%          4.12          0.00                   1.00         28.56
# max        428.00        115.92                   1.00       5000.00
#
#        congestion_surcharge  Airport_fee
# count            2824462.00   2824462.00
# mean                   2.26         0.14
# std                    0.82         0.49
# min                   -2.50        -1.75
# 25%                    2.50         0.00
# 50%                    2.50         0.00
# 75%                    2.50         0.00
# max                    2.50         1.75

# %%
df_iter = pd.read_csv('nyt.csv', iterator = True, chunksize = 100000)

# %%
df= next(df_iter)

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.head(0).to_sql(name = 'yellow_taxi_data',con = engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name = 'yellow_taxi_data',con = engine, if_exists='replace')
# Out:
# CPU times: user 2.73 s, sys: 38.2 ms, total: 2.77 s
# Wall time: 4.09 s
# 1000

# %%
from time import time

# %%
try:
    while True:
        t_start = time()

        try:
            df = next(df_iter)
        except StopIteration:
            print('No more data to process.')
            break
        df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
        df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

        try:
            df.to_sql(name = 'yellow_taxi_data',con = engine, if_exists='append')
        except Exception as e:
            print(f"Error inserting chunk into database: {e}")
            continue

        t_end = time()

        print(f"Inserted a chunk, took {t_end - t_start:.3f} seconds")
except Exception as e:
    print(f"An error ocurred during processing: {e}")
# Out:
# Inserted a chunk, took 4.375 seconds
# Inserted a chunk, took 4.164 seconds
# Inserted a chunk, took 4.340 seconds
# Inserted a chunk, took 4.311 seconds
# Inserted a chunk, took 4.200 seconds
# Inserted a chunk, took 4.173 seconds
# Inserted a chunk, took 4.741 seconds
# Inserted a chunk, took 5.337 seconds
# Inserted a chunk, took 5.247 seconds
# Inserted a chunk, took 4.547 seconds
# Inserted a chunk, took 4.578 seconds
# Inserted a chunk, took 4.476 seconds
# Inserted a chunk, took 5.052 seconds
# Inserted a chunk, took 4.384 seconds
# Inserted a chunk, took 4.466 seconds
# Inserted a chunk, took 4.627 seconds
# Inserted a chunk, took 4.843 seconds
# Inserted a chunk, took 4.717 seconds
# Inserted a chunk, took 4.592 seconds
# Inserted a chunk, took 4.467 seconds
# Inserted a chunk, took 4.970 seconds
# Inserted a chunk, took 4.517 seconds
# Inserted a chunk, took 4.632 seconds
# Inserted a chunk, took 4.842 seconds
# Inserted a chunk, took 4.549 seconds
# Inserted a chunk, took 4.767 seconds
# Inserted a chunk, took 5.062 seconds
# /tmp/ipykernel_23210/4056560070.py:6: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# Inserted a chunk, took 4.354 seconds
# Inserted a chunk, took 2.558 seconds
# No more data to process.
